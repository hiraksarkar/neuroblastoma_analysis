# %%
suppressPackageStartupMessages({
  library(GEOquery)
  library(stringr)
  library(dplyr)
  library(magrittr)
  library(tidyverse)
  library(survival)
    library(biomaRt)
    library(survminer)
    library(gridExtra)
})

# %%
fig.size <- function (height, width) {
    options(repr.plot.height = height, repr.plot.width = width)
}

# %%
data = readRDS(
    '/scratch/gpfs/KANG/hirak/mendel/Projects/neuroblastoma_analysis/results/Jansky_data/adrenal_medulla_Seurat.RDS'
)

# %%
data@assays
# Out:
# $RNA
# Assay data with 28422 features for 10739 cells
# Top 10 variable features:
#  IL1RAPL2, PDZRN4, HBG2, RANBP2, HSPH1, NKAIN2, ZNF804B, SLC35F3,
# RP11-308N19.1, HBA2

# %%
annot = readRDS(
    '/scratch/gpfs/KANG/hirak/mendel/Projects/neuroblastoma_analysis/results/Jansky_data/adrenal_medulla_annot.RDS'
)

# %%
annot %>% dim
# Out:
# [1] 10739   104

# %%
annot[,c('timepoint')]
# Out:
#     [1] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [10] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [19] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [28] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [37] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [46] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [55] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [64] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [73] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [82] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#    [91] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
#   [100] "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"  "7pcw"
# ...

# %%
adr.annot = readRDS(
    '/scratch/gpfs/KANG/hirak/mendel/Projects/neuroblastoma_analysis/results/Jansky_data/adrenal_gland_annot.RDS'
)

# %%
adr.annot %>% pull('timepoint') %>% unique
# Out:
# [1] "7pcw"  "8pcw"  "11pcw" "14pcw" "17pcw"

# %%
adr.annot[rownames(annot),] %>% dim
# Out:
# [1] 10739   109

# %%
print(data)

# %%
artem.obj = UpdateSeuratObject(adr)
