# %%
suppressPackageStartupMessages({
  library(Seurat)
  library(dplyr)
  library(ggplot2)
  library(scCustomize)
  library(scater)
    library(RColorBrewer)
    library(data.table)
    library(stringr)
library(tibble)
    library(tidyr)
})

# %%
fig.size <- function (height, width, res=300) {
    options(repr.plot.height = height, repr.plot.width = width, resolution=res)
}

# %%
obj = readRDS(
    "../../../fallopian_tube.rds"
)

# %%
obj
# Out:
# An object of class Seurat
# 60054 features across 60574 samples within 1 assay
# Active assay: RNA (60054 features, 0 variable features)
#  2 layers present: counts, data
#  3 dimensional reductions calculated: pca, tsne, umap

# %%
fig.size(10,10)
DimPlot(obj, reduction = "umap", group.by = "cell_type")
# Out:
# plot without title
